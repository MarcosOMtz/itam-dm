# %%
from IPython.display import Image
from IPython.lib.display import YouTubeVideo

# %%
Image("figure/mitam.png")

# %% [markdown]
# + [The Winning Entry](# ¿Naive Bayes... el mejor algoritmo de clasificación?)
# + [Overfitting](# ¿Por qué nos debe importar el Overfitting?)
# + [Feature Selection](# neuronas)
# + [Comparing the accuracy of learning methods](# noticias)
# + [Magical thinking](# neuronas)
# + [Economic issues](# noticias)
# + [Choice of learning method](# neuronas)

# %% [markdown]
# ---

# %% [markdown]
# ## ¿Naive Bayes... el mejor algoritmo de clasificación?

# %% [markdown]
# * Regla de Bayes
#
# $P(C|x) =$ $\frac{P(x|C)*P(C)} {P(X)}$
#
#
# ** Supuesto : Las probabilidades de clase son independientes: **
#
# $P(X,Y,Z|C) =$ ${P(X|C)*P(Y|C)*P(Z|C)}$

# %% [markdown]
# First,
# naive
# Bayesian
# classifiers
# remain
# competitive
# in
# practice:
# they
# were
# used
# by
# both
# the
# winning
# entry
# and
# the
# next
# best
# entry
# .
#
# Second,
# identifying
# feature
# interactions
# correctly
# is
# important
# for
# maximizing
# predictive
# accuracy:
# this
# was
# the
# difference
# between
# the
# winning
# classifier
# and
# all
# others.
#
# Third
# and
# most
# important,
# too
# many
# researchers
# and
# practitioners
# in
# data
# mining
# do
# not
# appreciate
# properly
# the
# issue
# of
# statistical
# significance
# and
# the
# danger
# of
# overfitting.
#
# Given
# a
# dataset
# such
# as
# the
# one
# for
# the
# CoIL
# contest,
# it
# is
# pointless
# to
# apply
# a
# very
# complicated
# learning
# algorithm,
# or
# to
# perform
# avery
# time-consuming
# model
# search.
#
# In
# either
# case,
# one
# is
# likely
# to
# overfit
# the
# training
# data
# and
# to
# fool
# oneself
# in
# estimating
# predictive
# accuracy
# and
# in
# discovering
# useful
# correlations

# %%
YouTubeVideo('3QPwQoD9exk', width=680, height=400
# Out:
#         <iframe
#             width="680"
#             height=400"
#             src="https://www.youtube.com/embed/3QPwQoD9exk"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# **Otros algoritmos:**

# %% [markdown]
# + Backpropagation neural networks
# + Self-organizing maps (SOM`s)
# + Evolutionary algoriths
# + C4.5 (arboles de decisión)
# + CART
# + Fuzzy clustering and rule discovery
# + Suport Vector Machine
# + Logistic regression
# + boosting and bagging

# %% [markdown]
# ##  ¿Por qué nos debe importar el Overfitting?

# %%
Image("figure/over1.png")

# %% [markdown]
# ** What is overfitting in data mining? **
#
# + A modeling error which occurs when a function is too closely fit to a limited
#     set of data points. Overfitting the model generally takes the form of making
#     an overly complex model to explain idiosyncrasies in the data under study.

# %%
Image("figure/over2.png")

# %% [markdown]
# **Why? **
#
# * In reality, the data being studied often has some degree of
# error or random noise within it.

# %% [markdown]
# ** Paper: **
#
# It is vital for data mining practitioners to understand the issue of overfitting in an
# intuitive way, and also to understand basic statistics in an intuitive way.
# Many contest submissions reveal basic misunderstandings about the issue of overfitting.
#
#
# For example, one team wrote that they used:
#      + Evolutionary search for choosing the predictive features.
#
#      + “The result is a predictive model that uses only a subset of the original features,
#         thus simplifying the model and reducing the risk of overfitting while
#         maintaining accuracy.”
#
#
# ** A ** = Overfitting occurs when a model is chosen whose high apparent accuracy arises
# from fitting patterns in the training set that are not statistically reliable,
# and are not valid in test data.
#
#
# Similarly, the danger of overfitting is not reduced just because a learning algorithm outputs a model with only a few parameters.
# “We haven’t got the best score. The possible ways for the improvement of the model are:
#
# +	increase of the number of neurons in the hidden layer what let us to consider a greater
#     number of the relationships among the data
# +	 use of the genetic algorithm for the neural network learning since one is more
#     effective in global extremum finding
#
# A= These suggestions would only increase the severity of overfitting…… is use all available
# training examples and apply a regularization method such as early stopping to reduce the
# risk of overfitting.
#
# A model that is too simple over generalizes. A model that is too complex over…?

# %% [markdown]
# ## Feature Selection

# %%
Image("figure/over3.png")

# %% [markdown]
# Most participants used heuristics to identify which of the available features have
# the most predictive value, and to choose a subset of features for input
# into their earning algorithm.
#
# “None of the authors of reports applied a well-defined algorithm for feature selection
# that did not require human guidance. Moreover, none of the authors, including myself,
# used a systematic method to detect important feature interactions.”
#
# Some participants used methods designed to evaluate subsets of features, as opposed to individual
# features, but these methods failed to detect the interaction..

# %% [markdown]
# ## Comparing the accuracy of learning methods

# %% [markdown]
# ## Magical Thinking

# %% [markdown]
# ## Economic Issues

# %% [markdown]
# ## Choice of learning method

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# ** First. **
#
# + Naive Bayesian learning gives both good predictive accuracy and interpretable models
# + new interaction features and boosting can improve accuracy without impairing comprehensibility.
#
# ** Second : negative **
#
# + The negative technical lesson is that reliable algorithms are still not available for doing feature subset selection and detecting feature interactions at the same time.
#
# ** Third **
#
# + There is a clear lack of awareness and understanding among some researchers and many practitioners in data mining of the issue of statistical significance. In many applications, the categories that we particularly want to model are rare.

# %%
from IPython.display import HTML
HTML('<iframe src=http://www.kdd.org/kdd2014/ width=850 height=550></iframe>')
# Out:
# <iframe src=http://www.kdd.org/kdd2014/ width=850 height=550></iframe>

# %% [markdown]
# ## Extras!! Extras!!

# %% [markdown]
# ### Ejemplos

# %%
# Paper del KDD 2010. importancia del Feature Engineering en competencias actuales
http://pslcdatashop.org/KDDCup/workshop/papers/kdd2010ntu.pdf

# Temas relacionados.
http://www.sigkdd.org/kddcup/index.php

# %%
YouTubeVideo('drUToKxEAUA', width=680, height=400)
# Out:
#         <iframe
#             width="680"
#             height=400"
#             src="https://www.youtube.com/embed/drUToKxEAUA"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
Image("figure/fs.png", width=400, height=2500)

# %% [markdown]
# #### Código Python.

# %%
#Gaussian Naive Bayes

from sklearn import datasets
froms klearn import metrics
from sklearn.naive_bayes import GaussianNB

#load the iris datasets
dataset = datasets.load_iris()

# fit a Naive Bayes model to the data 
model = GaussianNB()
model.fit(dataset.data,dataset.target)
print(model)

#make predictions
expected = dataset.target
predicted = model.predict(dataset.data)

# summarize the fit of the model
print(metrics.classification_report(expected,predicted))
print(metrics.confusion_matrix(expected,predicted))

# %% [markdown]
# #### Código R

# %%
# load the package
library(e1071)
data(iris)

#fit model 
fit <- naiveBayes(Species~.,data=iris) 

# summarize the fit
summary(fit)

# make predictions 
predictions <- predict(fit,iris[,1:4])

# summarizea ccuracy 
table(predictions,iris$Species)


Mucha información viene en el paquete: e1071.
